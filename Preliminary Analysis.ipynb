# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Data importing

# %%
Xtrain = pd.read_csv('raw data/input_training.csv',sep = ',',header = 0)
Xtrain.head()
# Out:
#    ID     ML1_0     ML1_1     ML1_2     ML1_3     ML1_4     ML1_5     ML1_6  \
# 0   0  0.021276  0.039363 -0.001475  0.023994  0.009620  0.036350  0.028983
# 1   1  0.018403  0.026159  0.009684  0.001014 -0.000866  0.002019  0.000617
# 2   2 -0.020974 -0.044294 -0.044097 -0.042136 -0.041125 -0.034392 -0.033026
# 3   3 -0.004381 -0.017433 -0.021386 -0.020316 -0.019849 -0.023615 -0.013923
# 4   4  0.022106  0.065815  0.060662  0.063035  0.065413  0.064131  0.061383
#
#       ML1_7     ML1_8    ...       V6_740    V6_741    V6_742    V6_743  \
# 0  0.031416  0.030435    ...    -0.003424 -0.007473 -0.008551 -0.011629
# 1 -0.011167 -0.026314    ...    -0.005327 -0.002014  0.001650  0.004635
# 2 -0.031817 -0.032347    ...    -0.068369 -0.059892 -0.055802 -0.041579
# 3  0.014080  0.088580    ...     0.376336  0.357924  0.333985  0.305791
# 4  0.059843  0.060229    ...    -0.015729 -0.014732 -0.014419 -0.014700
#
#      V6_744    V6_745    V6_746    V6_747    V6_748    V6_749
# ...

# %%
Ytrain = pd.read_csv('raw data/output_training.csv',sep = ';',header = 0)
Ytrain.head()
# Out:
#    ID  TARGET
# 0   0       1
# 1   1       1
# 2   2       1
# 3   3       1
# 4   4       0

# %%
Xtest = pd.read_csv('raw data/input_testing.csv',sep = ',',header = 0)
Xtest.head()
# Out:
#    ID     ML1_0     ML1_1     ML1_2     ML1_3     ML1_4     ML1_5     ML1_6  \
# 0   0  0.006981  0.004809  0.015296  0.020805  0.029253  0.034730  0.037978
# 1   1 -0.062234 -0.161833 -0.153454 -0.143299 -0.146753 -0.151027 -0.160705
# 2   2  0.009401  0.016941  0.017034  0.021094  0.016237  0.022418  0.024305
# 3   3  0.001130  0.003954  0.008546  0.013112  0.019059  0.026257  0.034082
# 4   4 -0.001161  0.000881  0.006006  0.012586  0.020381  0.030331  0.036365
#
#       ML1_7     ML1_8    ...       V6_740    V6_741    V6_742    V6_743  \
# 0  0.038167  0.036969    ...    -0.009474 -0.010455 -0.011250 -0.012187
# 1 -0.162273 -0.153067    ...     0.276871 -0.037408 -0.140377 -0.135779
# 2  0.022992  0.023456    ...     0.051747  0.052063  0.052441  0.052655
# 3  0.041802  0.048244    ...     0.055833  0.055847  0.054900  0.052792
# 4  0.038272  0.034458    ...    -0.008701 -0.011619 -0.013196 -0.013089
#
#      V6_744    V6_745    V6_746    V6_747    V6_748    V6_749
# ...

# %%
Xtrain.columns[1:750]
Xtrain.columns[751:751+750]
Xtrain.columns[751+750*10:751+750*11]
# Out:
# Index([u'V6_0', u'V6_1', u'V6_2', u'V6_3', u'V6_4', u'V6_5', u'V6_6', u'V6_7',
#        u'V6_8', u'V6_9',
#        ...
#        u'V6_740', u'V6_741', u'V6_742', u'V6_743', u'V6_744', u'V6_745',
#        u'V6_746', u'V6_747', u'V6_748', u'V6_749'],
#       dtype='object', length=750)

# %% [markdown]
# ## Sample function
#
# We will define a sample function for extracting datas from different channels (by indice from 1 to 12 & by ID from 0 to 4).

# %%
from ECG_function import *

# %%
#Test
DataSample(Xtrain,[1,2],3)
# Out:
#       ML3_0     ML3_1     ML3_2     ML3_3     ML3_4     ML3_5     ML3_6  \
# 1  0.000368 -0.002160 -0.004497 -0.006134 -0.005459 -0.003844 -0.003149
# 2  0.016568  0.037517  0.035063  0.035143  0.036901  0.036132  0.036647
#
#       ML3_7     ML3_8     ML3_9    ...      ML3_740   ML3_741   ML3_742  \
# 1 -0.004335 -0.006095 -0.006248    ...    -0.004131 -0.003545 -0.002869
# 2  0.036375  0.035232  0.033861    ...    -0.066095 -0.030852  0.029556
#
#     ML3_743   ML3_744   ML3_745   ML3_746   ML3_747   ML3_748   ML3_749
# 1 -0.002309 -0.001962 -0.001751 -0.001515 -0.001043 -0.000220  0.000895
# 2  0.046187  0.044581  0.042301  0.050770  0.070837  0.084942  0.086189
#
# [2 rows x 750 columns]

# %% [markdown]
# ## Some graphic interpretations
#
# We will plot the signals collected from all the channels of ID 1 and ID 4.

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5,ax6),(ax7, ax8, ax9), (ax10, ax11,ax12)) = plt.subplots(4, 3, sharex='col', sharey='row')
fig.set_size_inches(15, 15)

for (ax,i) in zip((ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12),range(1,13,1)):
    ax.plot(DataSample(Xtrain,1,i))
    ax.set_title('channel '+str(i))

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5,ax6),(ax7, ax8, ax9), (ax10, ax11,ax12)) = plt.subplots(4, 3, sharex='col', sharey='row')
fig.set_size_inches(15, 15)

for (ax,i) in zip((ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12),range(1,13,1)):
    ax.plot(DataSample(Xtrain,4,i))
    ax.set_title('channel '+str(i))

# %% [markdown]
# ## Preliminary Analysis
# We could see from the plot that all the signals are periodic, and it seems that the high frequency components will play an important role in classification. So the wavelet or fourier transformation maybe useful for getting the features of these signals.
